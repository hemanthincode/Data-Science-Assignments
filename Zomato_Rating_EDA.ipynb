# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-167f396c-1745-4331-8f39-ec839b51fc2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-167f396c-1745-4331-8f39-ec839b51fc2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Restaurant reviews.csv')
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...

# %%
df.columns
# Out:
# Index(['Restaurant', 'Reviewer', 'Review', 'Rating', 'Metadata', 'Time',
#        'Pictures'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant    object
# Reviewer      object
# Review        object
# Rating        object
# Metadata      object
# Time          object
# Pictures       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Restaurant  10000 non-null  object
#  1   Reviewer    9962 non-null   object
#  2   Review      9955 non-null   object
#  3   Rating      9962 non-null   object
#  4   Metadata    9962 non-null   object
#  5   Time        9962 non-null   object
#  6   Pictures    10000 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#            Pictures
# count  10000.000000
# mean       0.748600
# std        2.570381
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       64.000000

# %%
## In Data Analysis what all things we do
#  1.  Missing Values
#  2.  Explore about numerical variables
#  3.  Explore about categorical variables
#  4.  Finding relationsbetween features

# %%
df.isnull().sum()
# Out:
# Restaurant     0
# Reviewer      38
# Review        45
# Rating        38
# Metadata      38
# Time          38
# Pictures       0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()]
# Out:
# ['Reviewer', 'Review', 'Rating', 'Metadata', 'Time']

# %%
# prompt: give me code for heatmap to show null values in df

import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.dtypes
# Out:
# Restaurant    object
# Reviewer      object
# Review        object
# Rating        object
# Metadata      object
# Time          object
# Pictures       int64
# dtype: object

# %%
df['Restaurant'] = le.fit_transform(df['Restaurant'])
df['Reviewer'] = le.fit_transform(df['Reviewer'])
df['Review'] = le.fit_transform(df['Review'])
df['Rating'] = le.fit_transform(df['Rating'])
df['Metadata'] = le.fit_transform(df['Metadata'])
df['Time'] = le.fit_transform(df['Time'])

# %%
from sklearn.preprocessing import StandardScaler
sa = StandardScaler()

# %%
# prompt: give me the code to do the standardscaler for Pictures in df

df['Pictures'] = sa.fit_transform(df[['Pictures']])

# %%
df
# Out:
#       Restaurant  Reviewer  Review  Rating  Metadata  Time  Pictures
# 0             16      4976    5984       8        46  6480 -0.291255
# 1             16       766     516       8      1238  6465 -0.291255
# 2             16       955     185       8       792  6434 -0.291255
# 3             16      6595    5694       8        22  6427 -0.291255
# 4             16      1617    1747       8      1238  6423 -0.291255
# ...          ...       ...     ...     ...       ...   ...       ...
# 9995          20       167    4282       4      1864  7154 -0.291255
# 9996          20      5631    6786       7       820  7149 -0.291255
# 9997          20      4625     800       1      2067  7125  0.875945
# 9998          20      3591    3425       6       392  6572 -0.291255
# 9999          20      1182    1164       5      1723  6571  2.043146
#
# [10000 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Restaurant    0
# Reviewer      0
# Review        0
# Rating        0
# Metadata      0
# Time          0
# Pictures      0
# dtype: int64

# %%
df.Rating.value_counts()
# Out:
# Rating
# 8     3832
# 6     2373
# 0     1735
# 4     1193
# 2      684
# 7       69
# 5       47
# 10      38
# 3       19
# 1        9
# 9        1
# Name: count, dtype: int64

# %%
Ratings = df.Rating.value_counts().index
Ratings
# Out:
# Index([8, 6, 0, 4, 2, 7, 5, 10, 3, 1, 9], dtype='int64', name='Rating')

# %%
Ratings_values = Ratings.values
Ratings_values
# Out:
# array([ 8,  6,  0,  4,  2,  7,  5, 10,  3,  1,  9])

# %%
plt.pie(Ratings,labels=Ratings_values,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f53b6cb5900>,
# ...
#  [Text(0.9871382785832113, 0.4853431970840576, '8'),
#   Text(0.33991872319707334, 1.046162158377023, '6'),
#   Text(-0.03141162592472164, 1.0995514129665631, '0'),
#   Text(-0.2796401309397519, 1.0638615498118158, '4'),
#   Text(-0.6208874995985135, 0.9080191148000719, '2'),
#   Text(-0.9871382445023767, 0.48534326640097325, '7'),
#   Text(-1.0714131221024756, -0.2491463862604187, '5'),
#   Text(-0.5133340832884475, -0.9728762094605918, '10'),
#   Text(0.27964015584122837, -1.0638615432663658, '3'),
#   Text(0.5133340434377774, -0.972876230487631, '1'),
#   Text(0.9578206651499284, -0.5409062519621576, '9')],
#  [Text(0.538439061045388, 0.2647326529549405, '14.55%'),
#   Text(0.18541021265294907, 0.5706339045692852, '10.91%'),
#   Text(-0.017133614140757255, 0.5997553161635798, '0.00%'),
#   Text(-0.1525309805125919, 0.5802881180791721, '7.27%'),
#   Text(-0.33866590887191644, 0.4952831535273119, '3.64%'),
# ...

# %%
plt.pie(Ratings[:5],labels=Ratings_values[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f53b7306560>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, '8'),
#   Text(-1.0461621424642782, -0.3399187721714579, '6'),
#   Text(-0.3399185762739153, -1.046162206115244, '0'),
#   Text(0.3399188211458418, -1.0461621265515308, '4'),
#   Text(1.0461622140716127, -0.3399185517867209, '2')],
#  [Text(0.1854101859396479, 0.5706339132489631, '40.00%'),
#   Text(-0.5706338958896062, -0.18541023936624976, '30.00%'),
#   Text(-0.1854101325130447, -0.5706339306083149, '0.00%'),
#   Text(0.18541026607955005, -0.5706338872099259, '20.00%'),
#   Text(0.5706339349481523, -0.18541011915639322, '10.00%')])

# %%
df.groupby(['Restaurant', 'Rating']).size().unstack().plot(kind='bar')
fplt.show()

# %%
print(['Rating'==0])
# Out:
# [False]
